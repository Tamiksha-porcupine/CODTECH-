# %%
pip install sqlalchemy mysql-connector-python pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd

# ✅ Step 1: Define your MySQL connection string
# Replace 'root', 'your_password', and 'your_database' as needed
username = 'root'
password = 'tamiksha'
host = 'localhost'
database = 'sets'

# ✅ Step 2: Create SQLAlchemy engine
engine = create_engine(f"mysql+mysqlconnector://{username}:{password}@{host}/{database}")

# ✅ Step 3: Read from MySQL into Pandas DataFrames
try:
    imdb_df = pd.read_sql("SELECT * FROM imdb", con=engine)
    genres_df = pd.read_sql("SELECT * FROM genres", con=engine)

    print("✅ Data Loaded Successfully")

    print("\n🎬 IMDB Table:")
    display(imdb_df.head())

    print("\n🎮 GENRES Table:")
    display(genres_df.head())

except Exception as e:
    print("❌ Error occurred while fetching data:", e)

# ✅ Step 4: Optional — write data back to MySQL
# Example: Backup imdb table into a new one called imdb_backup
try:
    imdb_df.to_sql("imdb_backup", con=engine, if_exists="replace", index=False)
    print("✅ imdb_backup table created in MySQL.")
except Exception as e:
    print("❌ Error writing to MySQL:", e)

# ✅ Step 5: Close connection — optional, handled by SQLAlchemy automatically
# Out:
# ✅ Data Loaded Successfully
#
# 🎬 IMDB Table:
#    Sr_No                    Name  Year Certificate  Rating  Votes
# 0      1              Spider-Man  2018           T     9.2  20759
# 1      2  Red Dead Redemption II  2018           M     9.7  35703
# 2      3      Grand Theft Auto V  2013           M     9.5  59986
# 3      4              God of War  2018           M     9.9  26118
# 4      5             Injustice 2  2016           T     9.5  28722
# 🎮 GENRES Table:
#    Sr_No Action Adventure Comedy  Crime Family Fantasy Mystery Sci_Fi Thriller
# 0      1   TRUE      TRUE  FALSE  FALSE  FALSE    TRUE   FALSE  FALSE    FALSE
# 1      2   TRUE      TRUE  FALSE   TRUE  FALSE   FALSE   FALSE  FALSE    FALSE
# 2      3   TRUE     FALSE  FALSE   TRUE  FALSE   FALSE   FALSE  FALSE    FALSE
# 3      4   TRUE      TRUE  FALSE  FALSE  FALSE   FALSE   FALSE  FALSE    FALSE
# 4      5   TRUE      TRUE  FALSE  FALSE  FALSE   FALSE   FALSE  FALSE    FALSE
# ✅ imdb_backup table created in MySQL.
